# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_marks.csv')

# %%
df.head()
# Out:
#    Study_Hours  Attendance  Sleep_Hours  Previous_Marks  Final_Marks
# 0          5.0        80.0          7.0              65           70
# 1          6.0        85.0          6.0              70           75
# 2          4.0        78.0          8.0              60           68
# 3          7.0        90.0          6.0              75           80
# 4          8.0        92.0          5.0              80           85

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Study_Hours     13 non-null     float64
#  1   Attendance      14 non-null     float64
#  2   Sleep_Hours     14 non-null     float64
#  3   Previous_Marks  15 non-null     int64
#  4   Final_Marks     15 non-null     int64
# dtypes: float64(3), int64(2)
# memory usage: 732.0 bytes

# %%
target = "Final_Marks"

# %%
df.isnull().sum()
# Out:
# Study_Hours       2
# Attendance        1
# Sleep_Hours       1
# Previous_Marks    0
# Final_Marks       0
# dtype: int64

# %%
df.describe()
# Out:
#        Study_Hours  Attendance  Sleep_Hours  Previous_Marks  Final_Marks
# count    13.000000   14.000000    14.000000       15.000000    15.000000
# mean      5.538462   82.428571     6.357143       67.333333    73.133333
# std       1.983910    8.500808     0.928783        9.416298     9.093692
# min       2.000000   65.000000     5.000000       50.000000    55.000000
# 25%       4.000000   78.500000     6.000000       61.000000    69.000000
# 50%       6.000000   83.500000     6.000000       68.000000    74.000000
# 75%       7.000000   88.750000     7.000000       73.000000    78.500000
# max       9.000000   95.000000     8.000000       85.000000    90.000000

# %% [markdown]
# <!-- Look at Final_Marks
# Mean ≈ 73
# Median (50%) ≈ 74
# Data is balanced
#
# Min = 55
# Max = 90
# No extreme outliers
#
# Conclusion:
# The dataset does not contain significant outliers in the target variable -->

# %%
# STEP 2: Data Cleaning (Missing Values)
# Why cleaning is needed?
# Machine Learning models cannot handle missing values

# %%
df.fillna(df.median(),inplace = True)

# %%
df.isnull().sum()
# Out:
# Study_Hours       0
# Attendance        0
# Sleep_Hours       0
# Previous_Marks    0
# Final_Marks       0
# dtype: int64

# %%
df
# Out:
#     Study_Hours  Attendance  Sleep_Hours  Previous_Marks  Final_Marks
# 0           5.0        80.0          7.0              65           70
# 1           6.0        85.0          6.0              70           75
# 2           4.0        78.0          8.0              60           68
# 3           7.0        90.0          6.0              75           80
# 4           8.0        92.0          5.0              80           85
# 5           3.0        70.0          7.0              55           60
# 6           6.0        88.0          6.0              72           78
# 7           6.0        83.5          6.0              68           74
# 8           5.0        82.0          6.0              66           72
# 9           7.0        89.0          6.0              74           79
# 10          2.0        65.0          8.0              50           55
# 11          9.0        95.0          5.0              85           90
# 12          4.0        75.0          7.0              58           65
# 13          6.0        80.0          6.0              62           70
# 14          6.0        85.0          6.0              70           76

# %%
#STEP 3: Exploratory Data Analysis (EDA)

# %%
#Correlation Analysis
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#Distribution of Target Variable
df["Final_Marks"].hist()
plt.title("Distribution of final marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
# STEP 4: Feature & Target Separation
# Split input and output
X = df.drop("Final_Marks", axis = 1)

# %%
y = df["Final_Marks"]

# %%
X
# Out:
#     Study_Hours  Attendance  Sleep_Hours  Previous_Marks
# 0           5.0        80.0          7.0              65
# 1           6.0        85.0          6.0              70
# 2           4.0        78.0          8.0              60
# 3           7.0        90.0          6.0              75
# 4           8.0        92.0          5.0              80
# 5           3.0        70.0          7.0              55
# 6           6.0        88.0          6.0              72
# 7           6.0        83.5          6.0              68
# 8           5.0        82.0          6.0              66
# 9           7.0        89.0          6.0              74
# 10          2.0        65.0          8.0              50
# 11          9.0        95.0          5.0              85
# 12          4.0        75.0          7.0              58
# 13          6.0        80.0          6.0              62
# 14          6.0        85.0          6.0              70

# %%
y
# Out:
# 0     70
# 1     75
# 2     68
# 3     80
# 4     85
# 5     60
# 6     78
# 7     74
# 8     72
# 9     79
# 10    55
# 11    90
# 12    65
# 13    70
# 14    76
# Name: Final_Marks, dtype: int64

# %%
#STEP 5: Train–Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)
#Why split?
#To test model on unseen data.

# %%
X_train
# Out:
#     Study_Hours  Attendance  Sleep_Hours  Previous_Marks
# 8           5.0        82.0          6.0              66
# 2           4.0        78.0          8.0              60
# 1           6.0        85.0          6.0              70
# 14          6.0        85.0          6.0              70
# 4           8.0        92.0          5.0              80
# 7           6.0        83.5          6.0              68
# 10          2.0        65.0          8.0              50
# 12          4.0        75.0          7.0              58
# 3           7.0        90.0          6.0              75
# 6           6.0        88.0          6.0              72

# %%
X_test
# Out:
#     Study_Hours  Attendance  Sleep_Hours  Previous_Marks
# 9           7.0        89.0          6.0              74
# 11          9.0        95.0          5.0              85
# 0           5.0        80.0          7.0              65
# 13          6.0        80.0          6.0              62
# 5           3.0        70.0          7.0              55

# %%
y_train
# Out:
# 8     72
# 2     68
# 1     75
# 14    76
# 4     85
# 7     74
# 10    55
# 12    65
# 3     80
# 6     78
# Name: Final_Marks, dtype: int64

# %%
y_test
# Out:
# 9     79
# 11    90
# 0     70
# 13    70
# 5     60
# Name: Final_Marks, dtype: int64

# %%
#STEP 6: Train Linear Regression Model
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([80.04409488, 88.4523752 , 70.75499065, 70.10905609, 60.21362933])

# %%
#STEP 8: Model Evaluation
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
print("mean_absolute_error",mean_absolute_error(y_test,y_pred))
# Out:
# mean_absolute_error 0.7338791506724306

# %%
print("mean_squared_error",mean_squared_error(y_test,y_pred))
# Out:
# mean_squared_error 0.8225636494205126

# %%
print("r2_score",r2_score(y_test,y_pred))
# Out:
# r2_score 0.9919166308036507
